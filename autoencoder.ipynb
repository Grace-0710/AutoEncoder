# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
from utils import load_mnist
from trainer import Trainer

# %%
from argparse import Namespace

config = {
    'train_ratio': .8,
    'batch_size': 256,
    'n_epochs': 50,
    'verbose': 1,
    'btl_size': 2
}

config = Namespace(**config)

print(config)
# Out:
# Namespace(batch_size=256, btl_size=2, n_epochs=50, train_ratio=0.8, verbose=1)

# %%
def show_image(x):
    if x.dim() == 1:
        x = x.view(int(x.size(0) ** .5), -1)
    
    plt.imshow(x, cmap='gray')
    plt.show()

# %%
train_x, train_y = load_mnist(flatten=True)
test_x, test_y = load_mnist(is_train=False, flatten=True)

train_cnt = int(train_x.size(0) * config.train_ratio)
valid_cnt = train_x.size(0) - train_cnt

# Shuffle dataset to split into train/valid set.
indices = torch.randperm(train_x.size(0))
train_x, valid_x = torch.index_select(
    train_x,
    dim=0,
    index=indices
).split([train_cnt, valid_cnt], dim=0)
train_y, valid_y = torch.index_select(
    train_y,
    dim=0,
    index=indices
).split([train_cnt, valid_cnt], dim=0)

print("Train:", train_x.shape, train_y.shape)
print("Valid:", valid_x.shape, valid_y.shape)
print("Test:", test_x.shape, test_y.shape)
# Out:
# Train: torch.Size([48000, 784]) torch.Size([48000])
# Valid: torch.Size([12000, 784]) torch.Size([12000])
# Test: torch.Size([10000, 784]) torch.Size([10000])

# %%
from model import Autoencoder

# %%
model = Autoencoder(btl_size=config.btl_size)
optimizer = optim.Adam(model.parameters())
crit = nn.MSELoss()

trainer = Trainer(model, optimizer, crit)

# %%
trainer.train((train_x, train_x), (valid_x, valid_x), config)
# Out:
# Epoch(1/50): train_loss=7.2033e-02  valid_loss=5.0033e-02  lowest_loss=5.0033e-02
# Epoch(2/50): train_loss=4.7503e-02  valid_loss=4.4709e-02  lowest_loss=4.4709e-02
# Epoch(3/50): train_loss=4.4758e-02  valid_loss=4.2861e-02  lowest_loss=4.2861e-02
# Epoch(4/50): train_loss=4.3379e-02  valid_loss=4.3112e-02  lowest_loss=4.2861e-02
# Epoch(5/50): train_loss=4.2550e-02  valid_loss=4.1273e-02  lowest_loss=4.1273e-02
# Epoch(6/50): train_loss=4.1644e-02  valid_loss=4.0086e-02  lowest_loss=4.0086e-02
# Epoch(7/50): train_loss=4.1633e-02  valid_loss=4.0123e-02  lowest_loss=4.0086e-02
# Epoch(8/50): train_loss=4.1135e-02  valid_loss=3.9418e-02  lowest_loss=3.9418e-02
# Epoch(9/50): train_loss=4.0644e-02  valid_loss=3.9556e-02  lowest_loss=3.9418e-02
# Epoch(10/50): train_loss=4.0242e-02  valid_loss=3.9303e-02  lowest_loss=3.9303e-02
# Epoch(11/50): train_loss=3.9973e-02  valid_loss=3.8907e-02  lowest_loss=3.8907e-02
# Epoch(12/50): train_loss=3.9768e-02  valid_loss=3.8344e-02  lowest_loss=3.8344e-02
# Epoch(13/50): train_loss=3.9459e-02  valid_loss=3.8414e-02  lowest_loss=3.8344e-02
# Epoch(14/50): train_loss=3.9532e-02  valid_loss=3.8425e-02  lowest_loss=3.8344e-02
# Epoch(15/50): train_loss=3.9445e-02  valid_loss=3.8371e-02  lowest_loss=3.8344e-02
# Epoch(16/50): train_loss=3.9294e-02  valid_loss=3.7762e-02  lowest_loss=3.7762e-02
# Epoch(17/50): train_loss=3.8910e-02  valid_loss=3.7558e-02  lowest_loss=3.7558e-02
# Epoch(18/50): train_loss=3.9296e-02  valid_loss=3.7463e-02  lowest_loss=3.7463e-02
# Epoch(19/50): train_loss=3.8705e-02  valid_loss=3.7396e-02  lowest_loss=3.7396e-02
# Epoch(20/50): train_loss=3.8598e-02  valid_loss=3.7219e-02  lowest_loss=3.7219e-02
# Epoch(21/50): train_loss=3.8464e-02  valid_loss=3.7964e-02  lowest_loss=3.7219e-02
# Epoch(22/50): train_loss=3.8540e-02  valid_loss=3.7106e-02  lowest_loss=3.7106e-02
# Epoch(23/50): train_loss=3.8297e-02  valid_loss=3.7350e-02  lowest_loss=3.7106e-02
# Epoch(24/50): train_loss=3.8490e-02  valid_loss=3.7253e-02  lowest_loss=3.7106e-02
# Epoch(25/50): train_loss=3.8189e-02  valid_loss=3.7022e-02  lowest_loss=3.7022e-02
# Epoch(26/50): train_loss=3.8305e-02  valid_loss=3.7874e-02  lowest_loss=3.7022e-02
# Epoch(27/50): train_loss=3.7955e-02  valid_loss=3.6837e-02  lowest_loss=3.6837e-02
# Epoch(28/50): train_loss=3.7823e-02  valid_loss=3.6532e-02  lowest_loss=3.6532e-02
# Epoch(29/50): train_loss=3.7944e-02  valid_loss=3.6481e-02  lowest_loss=3.6481e-02
# Epoch(30/50): train_loss=3.7478e-02  valid_loss=3.6557e-02  lowest_loss=3.6481e-02
# Epoch(31/50): train_loss=3.7298e-02  valid_loss=3.6243e-02  lowest_loss=3.6243e-02
# Epoch(32/50): train_loss=3.7371e-02  valid_loss=3.6436e-02  lowest_loss=3.6243e-02
# Epoch(33/50): train_loss=3.7324e-02  valid_loss=3.6106e-02  lowest_loss=3.6106e-02
# Epoch(34/50): train_loss=3.7128e-02  valid_loss=3.5779e-02  lowest_loss=3.5779e-02
# Epoch(35/50): train_loss=3.7024e-02  valid_loss=3.5955e-02  lowest_loss=3.5779e-02
# Epoch(36/50): train_loss=3.7052e-02  valid_loss=3.6417e-02  lowest_loss=3.5779e-02
# Epoch(37/50): train_loss=3.7023e-02  valid_loss=3.6145e-02  lowest_loss=3.5779e-02
# Epoch(38/50): train_loss=3.6911e-02  valid_loss=3.6718e-02  lowest_loss=3.5779e-02
# Epoch(39/50): train_loss=3.7001e-02  valid_loss=3.6402e-02  lowest_loss=3.5779e-02
# Epoch(40/50): train_loss=3.7303e-02  valid_loss=3.7543e-02  lowest_loss=3.5779e-02
# Epoch(41/50): train_loss=3.7717e-02  valid_loss=3.7206e-02  lowest_loss=3.5779e-02
# Epoch(42/50): train_loss=3.7320e-02  valid_loss=3.5844e-02  lowest_loss=3.5779e-02
# Epoch(43/50): train_loss=3.7068e-02  valid_loss=3.5857e-02  lowest_loss=3.5779e-02
# Epoch(44/50): train_loss=3.6698e-02  valid_loss=3.5899e-02  lowest_loss=3.5779e-02
# Epoch(45/50): train_loss=3.6811e-02  valid_loss=3.5806e-02  lowest_loss=3.5779e-02
# Epoch(46/50): train_loss=3.6601e-02  valid_loss=3.5814e-02  lowest_loss=3.5779e-02
# Epoch(47/50): train_loss=3.6546e-02  valid_loss=3.5532e-02  lowest_loss=3.5532e-02
# Epoch(48/50): train_loss=3.6470e-02  valid_loss=3.5681e-02  lowest_loss=3.5532e-02
# Epoch(49/50): train_loss=3.6214e-02  valid_loss=3.5071e-02  lowest_loss=3.5071e-02
# Epoch(50/50): train_loss=3.6059e-02  valid_loss=3.5457e-02  lowest_loss=3.5071e-02

# %% [markdown]
# ## Test

# %%
with torch.no_grad():
    import random

    index = int(random.random() * test_x.size(0))

    recon = model(test_x[index].view(1, -1)).squeeze()

    show_image(test_x[index])
    show_image(recon)

# %% [markdown]
# ## Latent Space
#
# ![스크린샷 2023-03-18 오후 12.34.40.png](data:image/png;base64,...)

# %%
if config.btl_size == 2:
    color_map = [
        'brown', 'red', 'orange', 'yellow', 'green',
        'blue', 'navy', 'purple', 'gray', 'black',
    ]
    
    plt.figure(figsize=(20, 10))
    with torch.no_grad():
        latents = model.encoder(test_x[:1000]) # Z가 1000개 나와용 |latents| = (1000,2)
        
        # latents를 색별로 찍어주기
        for i in range(10):
            target_latents = latents[test_y[:1000] == i]
            target_y = test_y[:1000][test_y[:1000] == i]
            plt.scatter(target_latents[:, 0],
                        target_latents[:, 1],
                        marker='o',
                        color=color_map[i],
                        label=i)
        
        plt.legend()
        plt.grid(axis='both')
        plt.show()

# %% [markdown]
# ![스크린샷 2023-03-18 오후 12.41.10.png](data:image/png;base64,...)
#
#
# 저 중간중간 네모박스들을 디코더에 통과시켜,

# %%
if config.btl_size == 2:
    min_range, max_range = -2., 2. # 영역
    n = 20 # 20저 샘플링
    step = (max_range - min_range) / float(n)
    
    # 학습이 아니라 추론
    with torch.no_grad():
      # with torch.no_grad() : gradient 계산을 비활성화한 컨텍스트 관리자
        lines = []

        for v1 in np.arange(min_range, max_range, step):
            z = torch.stack([
                torch.FloatTensor([v1] * n),
                torch.FloatTensor([v2 for v2 in np.arange(min_range,
                                                          max_range, step)]),
            ], dim=-1)
            
            line = torch.clamp(model.decoder(z).view(n, 28, 28), 0, 1)
            line = torch.cat([line[i] for i in range(n - 1, 0, -1)], dim=0)
            lines += [line]
            
        lines = torch.cat(lines, dim=-1)
        plt.figure(figsize=(20, 20))
        show_image(lines)

# %% [markdown]
# ![스크린샷 2023-03-18 오후 12.53.02.png](data:image/png;base64,...)
